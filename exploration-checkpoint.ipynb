# %%
import fitz

def extract_text_from_pdf(pdf_path):
    doc = fitz.open(pdf_path)
    pages = []

    for page_number in range(len(doc)):
        page = doc[page_number]
        text = page.get_text("text")

        pages.append({
            "page_number": page_number + 1,
            "text": text.strip()
        })

    return pages

# %%
pdf_path = "test_pdf_1.pdf"

# %%
pages = extract_text_from_pdf(pdf_path)

# %%
print("Total pages:", len(pages))
print("\nFirst 1000 characters:\n")
print(pages[17]["text"][:1000])
# Out:
# Total pages: 36
#
# First 1000 characters:
#
# Tenant Floors
# Max Towers provides you with a state-of-the-art blank slate workspace
# that you can fully customise to suit your needs.
# Designed such that 90% of regular occupied space gets direct
# line-of-sight to the outside environment, the average ceiling height on
# our tenant ﬂoor plates is 4.3 metres. Combined with optimum column
# spacing for eﬃcient ﬂoor planning, raised ﬂooring and a 10.5 meter
# planning grid, our spaces are agile, empowering you to build your
# workplace the way you want.
# Above and facing page Oﬃces at Max Towers
# 35
# 34

# %%
import os
pdf_data = {}

pdf_folder = "pdfs"  # folder containing PDFs

for filename in os.listdir(pdf_folder):
    if filename.endswith(".pdf"):
        path = os.path.join(pdf_folder, filename)
        pdf_data[filename] = extract_text_from_pdf(path)

print("Loaded PDFs:", list(pdf_data.keys()))
# Out:
# Loaded PDFs: ['test_pdf_1.pdf', 'test_pdf_2.pdf', 'test_pdf_3.pdf', 'test_pdf_4.pdf']

# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: spacy in c:\users\asus\real-estate-rag\venv\lib\site-packages (3.8.11)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from spacy) (8.3.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from spacy) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.4.2 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from spacy) (0.4.3)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from spacy) (0.23.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from spacy) (4.67.3)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from spacy) (2.4.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from spacy) (2.32.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from spacy) (2.12.5)
# Requirement already satisfied: jinja2 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\asus\real-estate-rag\venv\lib\site-packages (from spacy) (82.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from spacy) (26.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.1.4)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: colorama in c:\users\asus\real-estate-rag\venv\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: typer>=0.23.1 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from typer-slim<1.0.0,>=0.3.0->spacy) (0.23.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from weasel<0.5.0,>=0.4.2->spacy) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from weasel<0.5.0,>=0.4.2->spacy) (7.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from jinja2->spacy) (3.0.3)
# Requirement already satisfied: wrapt in c:\users\asus\real-estate-rag\venv\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.4.2->spacy) (2.1.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from typer>=0.23.1->typer-slim<1.0.0,>=0.3.0->spacy) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from typer>=0.23.1->typer-slim<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from typer>=0.23.1->typer-slim<1.0.0,>=0.3.0->spacy) (14.3.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from typer>=0.23.1->typer-slim<1.0.0,>=0.3.0->spacy) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from rich>=10.11.0->typer>=0.23.1->typer-slim<1.0.0,>=0.3.0->spacy) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from rich>=10.11.0->typer>=0.23.1->typer-slim<1.0.0,>=0.3.0->spacy) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.23.1->typer-slim<1.0.0,>=0.3.0->spacy) (0.1.2)
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      -- ------------------------------------- 0.8/12.8 MB 7.2 MB/s eta 0:00:02
#      --------- ------------------------------ 2.9/12.8 MB 10.4 MB/s eta 0:00:01
#      ------------------ --------------------- 6.0/12.8 MB 12.2 MB/s eta 0:00:01
#      ------------------------------ -------- 10.0/12.8 MB 13.9 MB/s eta 0:00:01
#      --------------------------------------- 12.8/12.8 MB 14.0 MB/s eta 0:00:00
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
import re

def preprocess(text):
    text = re.sub(r'-\n', '', text)   
    text = re.sub(r'\n+', ' ', text)  
    text = re.sub(r'\s+', ' ', text)  

    return text.strip()

# %%
def spacy_chunk(text, max_chars=700):
    doc = nlp(text)
    chunks = []
    current_chunk = ""

    for sent in doc.sents:
        sentence = sent.text.strip()

        if len(current_chunk) + len(sentence) <= max_chars:
            current_chunk += " " + sentence
        else:
            chunks.append(current_chunk.strip())
            current_chunk = sentence

    if current_chunk:
        chunks.append(current_chunk.strip())

    return chunks

# %%
# !pip install langchain langchain-community langchain-core
# Out:
# Requirement already satisfied: langchain in c:\users\asus\real-estate-rag\venv\lib\site-packages (1.2.10)
# Requirement already satisfied: langchain-community in c:\users\asus\real-estate-rag\venv\lib\site-packages (0.4.1)
# Requirement already satisfied: langchain-core in c:\users\asus\real-estate-rag\venv\lib\site-packages (1.2.12)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.8 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from langchain) (1.0.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from langchain-community) (1.0.1)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from langchain-community) (2.0.46)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from langchain-community) (3.13.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from langchain-community) (9.1.4)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from langchain-community) (0.7.3)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=2.1.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from langchain-community) (2.4.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from langchain-core) (26.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from langchain-core) (0.14.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.0.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (4.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.7 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (1.0.7)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (0.3.5)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (3.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2026.1.4)
# Requirement already satisfied: greenlet>=1 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.3.1)
# Requirement already satisfied: anyio in c:\users\asus\real-estate-rag\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (4.12.1)
# Requirement already satisfied: httpcore==1.* in c:\users\asus\real-estate-rag\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.8->langchain) (1.12.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

splitter = RecursiveCharacterTextSplitter(
    chunk_size=350,        # ~250-350 words
    chunk_overlap=100,     # IMPORTANT
    separators=["\n\n", "\n", ".", " "]
)

documents = []

for pdf_name, pages in pdf_data.items():
    for page in pages:
        chunks = splitter.split_text(page["text"])

        for chunk in chunks:
            documents.append({
                "text": chunk,
                "pdf_name": pdf_name,
                "page_number": page["page_number"]
            })


print("Total document chunks:", len(documents))
# Out:
# Total document chunks: 375

# %%
documents[1]
# Out:
# {'text': '“It’s not what went into a building, \nit’s what’ll come out of it.”\n— Jonathan Ive\nChief Design Oﬃcer, Apple\nMax Towers at dusk  \nas seen from the plaza  \ninside Delhi One\n3\n2',
#  'pdf_name': 'test_pdf_1.pdf',
#  'page_number': 2}

# %%
# !pip install sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\asus\real-estate-rag\venv\lib\site-packages (5.2.2)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from sentence-transformers) (5.1.0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from sentence-transformers) (1.4.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from sentence-transformers) (2.10.0)
# Requirement already satisfied: numpy in c:\users\asus\real-estate-rag\venv\lib\site-packages (from sentence-transformers) (2.4.2)
# Requirement already satisfied: scikit-learn in c:\users\asus\real-estate-rag\venv\lib\site-packages (from sentence-transformers) (1.8.0)
# Requirement already satisfied: scipy in c:\users\asus\real-estate-rag\venv\lib\site-packages (from sentence-transformers) (1.17.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: tqdm in c:\users\asus\real-estate-rag\venv\lib\site-packages (from sentence-transformers) (4.67.3)
# Requirement already satisfied: filelock in c:\users\asus\real-estate-rag\venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.21.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: shellingham in c:\users\asus\real-estate-rag\venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.5.4)
# Requirement already satisfied: typer-slim in c:\users\asus\real-estate-rag\venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (0.23.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\asus\real-estate-rag\venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (82.0.0)
# Requirement already satisfied: colorama in c:\users\asus\real-estate-rag\venv\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.1.15)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from scikit-learn->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: anyio in c:\users\asus\real-estate-rag\venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (4.12.1)
# Requirement already satisfied: certifi in c:\users\asus\real-estate-rag\venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\asus\real-estate-rag\venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (1.0.9)
# Requirement already satisfied: idna in c:\users\asus\real-estate-rag\venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (0.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: typer>=0.23.1 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from typer-slim->huggingface-hub>=0.20.0->sentence-transformers) (0.23.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from typer>=0.23.1->typer-slim->huggingface-hub>=0.20.0->sentence-transformers) (8.3.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from typer>=0.23.1->typer-slim->huggingface-hub>=0.20.0->sentence-transformers) (14.3.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from typer>=0.23.1->typer-slim->huggingface-hub>=0.20.0->sentence-transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from rich>=10.11.0->typer>=0.23.1->typer-slim->huggingface-hub>=0.20.0->sentence-transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from rich>=10.11.0->typer>=0.23.1->typer-slim->huggingface-hub>=0.20.0->sentence-transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.23.1->typer-slim->huggingface-hub>=0.20.0->sentence-transformers) (0.1.2)
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer("all-MiniLM-L6-v2")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100%|█████████████████████| 103/103 [00:00<00:00, 892.88it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
texts = [doc["text"] for doc in documents]

embeddings = model.encode(
    texts,
    convert_to_numpy=True,
    normalize_embeddings=True
)


print("Embedding shape:", embeddings.shape)
# Out:
# Embedding shape: (375, 384)

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# %%
def retrieve(query, top_k=3):
    query_embedding = model.encode([query], convert_to_numpy=True)
    
    similarities = cosine_similarity(query_embedding, embeddings)[0]
    
    top_indices = np.argsort(similarities)[-top_k:][::-1]
    
    results = [(documents[i], similarities[i]) for i in top_indices]
    
    return results

# %%
results = retrieve("What is the ceiling height?")

for chunk, score in results:
    print("\nScore:", score)
    print(chunk)
# Out:
# Score: 0.56067395
# {'text': 'Wooden wall finish & panelling\nHigh ceilings with a height of 3.75 meters\nEfficient floor plates with a clean, efficient rectangular design \nPlants and nature wherever you look \nLobby of Max House\n\x1a', 'pdf_name': 'test_pdf_2.pdf', 'page_number': 7}
#
# Score: 0.55218077
# {'text': 'RESIDENCES\nGenerous ceiling height of 10.5ft \nAll residences have been designed  \nto have their own private gardens\nViews from every residence have \nbeen carefully curated to capture the \nstunning natural landscape\nProvision for 2 car parking spaces in \nevery residence\nPublic areas such as kitchen, staff \nrooms, service and utility have been', 'pdf_name': 'test_pdf_3.pdf', 'page_number': 31}
#
# Score: 0.5036244
# {'text': 'Generous ceiling height (10.5 ft)\nMaintenance free facade\nInsulated premium windows\nPerlato marble ﬂooring\nLandscaped terrace\nCOURTYARD VILLAS\nUnits 5\nPlot size range 364-565 sq.m.\nBuilt up area 4197 sq.ft.²\nCarpet area 3276 sq.ft.²\nBalcony area 130 sq.ft.²', 'pdf_name': 'test_pdf_3.pdf', 'page_number': 18}

# %%
# !pip install faiss-cpu
# Out:
# Requirement already satisfied: faiss-cpu in c:\users\asus\real-estate-rag\venv\lib\site-packages (1.13.2)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from faiss-cpu) (2.4.2)
# Requirement already satisfied: packaging in c:\users\asus\real-estate-rag\venv\lib\site-packages (from faiss-cpu) (26.0)
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import faiss
import numpy as np

# %%
import numpy as np

# Normalize embeddings
faiss.normalize_L2(embeddings)

# %%
dimension = embeddings.shape[1]

index = faiss.IndexFlatIP(dimension)  # Inner Product (cosine similarity after normalization)
index.add(embeddings)

print("Total vectors in index:", index.ntotal)
# Out:
# Total vectors in index: 375

# %%
def retrieve_faiss(query, top_k=3):
    query_embedding = model.encode([query], convert_to_numpy=True)
    
    # Normalize query vector
    faiss.normalize_L2(query_embedding)
    
    distances, indices = index.search(query_embedding, top_k)
    
    results = []
    for i in range(top_k):
        results.append((documents[indices[0][i]], distances[0][i]))
    
    return results

# %%
results = retrieve_faiss("How long does it take to reach suryaa hotel from Max House?")



def clean_text(text):
    text = text.replace("\n", " ")
    text = re.sub(r"\s+", " ", text)
    text = re.sub(r"\s([?.!,'])", r"\1", text)
    return text.strip()

for chunk, score in results:
    chunk["text"] = clean_text(chunk["text"])

for chunk, score in results:
    print("\nScore:", score)
    print(chunk)
# Out:
# Score: 0.6477129
# {'text': "The Suryaa 5 minutes Eros Hotel 9 minutes Crowne Plaza 15 minutes Sarovar Portico 8 minutes Strategically located within walking distance of the Okhla NSIC Metro Station, Max House offers excellent accessibility and connectivity to Delhi's various central business districts, airports and residential neighbourhoods. \x16", 'pdf_name': 'test_pdf_2.pdf', 'page_number': 3}
#
# Score: 0.596907
# {'text': '25 minutes Terminal 1D (Airport) 30 minutes MG Road (Gurgaon) 40 minutes Jasola 8 minutes -Iپ\x03WN\x033IQTI[P 8 minutes New Friends Colony 10 minutes Greater Kailash 10 minutes Connaught Place 22 minutes Kalkaji Interconnect Walking distance 0W\\MT[,ZQ^QVO\x03<QUM The Suryaa 5 minutes Eros Hotel 9 minutes Crowne Plaza 15 minutes Sarovar Portico 8 minutes', 'pdf_name': 'test_pdf_2.pdf', 'page_number': 3}
#
# Score: 0.51668584
# {'text': "station, Max Towers provides excellent connectivity to Delhi's various central business districts, airports and residential neighbourhoods. Facing page Aerial view of Max Towers and Delhi One Sector 16 Metro Station 0.7 km 5 min Connaught Place 15 km 25 min IGI Airport 25 km 45 min Saket 18 km 30 min Gurgaon 32 km 55 min Jasola 12 km 20 min", 'pdf_name': 'test_pdf_1.pdf', 'page_number': 33}

# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-3.0.0-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from pandas) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\asus\real-estate-rag\venv\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\asus\real-estate-rag\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.0-cp313-cp313-win_amd64.whl (9.7 MB)
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---------- ----------------------------- 2.6/9.7 MB 17.5 MB/s eta 0:00:01
#    ------------------------------- -------- 7.6/9.7 MB 21.5 MB/s eta 0:00:01
#    ---------------------------------------- 9.7/9.7 MB 21.2 MB/s eta 0:00:00
# Installing collected packages: pandas
# Successfully installed pandas-3.0.0
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

eval_df = pd.read_csv("evaluation_questions.csv", encoding="cp1252")

# %%
eval_df
# Out:
#     id                                           question  \
# 0    1  Does the project - Max Towers mention any cert...
# 1    2  At Max Towers, solar heat gain is controlled t...
# 2    3                 Most prime location of max towers?
# 3    4                  when was max estates established?
# 4    5  What is the Solar Heat Gain Coefficient (SHGC)...
# 5    6  What percentage of visible light transmission ...
# 6    7  What is the total Super Built Up Area of Max H...
# 7    8  What is the green building certification ratin...
# 8    9  How long does it take to reach suryaa hotel fr...
# 9   10         How far is Connaught Place from Max House?
# 10  11  What sustainability certification has Max Squa...
# 11  12  What is the total number of parking levels at ...
# 12  13  Which airport terminal is specifically mention...
# 13  14  Which airport is mentioned as upcoming near Ma...
# 14  15  What is the name of the central courtyard fore...
# 15  16   What is the green building rating of Max Towers?
# 16  17  What is the minimum ceiling height on office f...
# 17  18     What is the super built-up area of Max Towers?
# 18  19                What is the parking ratio provided?
# 19  20   Which seismic zone is the building designed for?
#
#    expected_answer_keyword
# 0                   UPRERA
# 1             vertical-fin
# 2                    Noida
# 3                     2016
# 4                     0.25
# 5                      34%
# 6                 1,05,000
# 7                LEED Gold
# 8                        5
# 9                       11
# 10           IGBC Platinum
# 11                       4
# 12             Terminal 1D
# 13                   Jewar
# 14               Courtyard
# 15           LEED Platinum
# 16                     4.3
# 17                   52016
# 18                     700
# 19                  zone 4

# %%
import numpy as np
import time

# %%
for _, row in eval_df.iterrows():
    question = row["question"]
    results = retrieve_faiss(question)

# %%
len(results)
# Out:
# 3

# %%
for _, row in eval_df.iterrows():
    question = row["question"]

    print("\n" + "="*80)
    print("Question:", question)

    results = retrieve_faiss(question, top_k=3)

    for i, (chunk, score) in enumerate(results):
        print(f"\nTop {i+1} | Score: {score}")
        print("PDF:", chunk["pdf_name"])
        print("Page:", chunk["page_number"])
        print("Answer Chunk:\n", chunk["text"])
# Out:
# ================================================================================
# Question: Does the project - Max Towers mention any certifications, approvals, or RERA registration?
#
# Top 1 | Score: 0.7475370168685913
# PDF: test_pdf_1.pdf
# Page: 36
# Answer Chunk:
#  The project 'Max Towers' is registered with the UPRERA with registration no. UPRERAPRJ12475.
# Please refer to project details on the website of UPRERA www.up-rera.in.
# OWNERSHIP
# We would love to see you soon.
# For a visit to our experience centre and the site, contact us at
# +91- 95553 95222
# info@maxestates.in
# www.maxtowers.com
#
# Top 2 | Score: 0.726293683052063
# PDF: test_pdf_2.pdf
# Page: 15
# Answer Chunk:
#  CIN : U70109UP2016PTC087374. Its Occupation Certificate has been received on21.12.2018. The project 'Max Towers' is registered with the UPRERA with registration no. UPRERAPRJ12475.
# Please refer to project details on the website of UPRERA www.up-rera.in.
#
# Top 3 | Score: 0.7247656583786011
# PDF: test_pdf_3.pdf
# Page: 35
# Answer Chunk:
#  on 21.12.2018. The project 'Max Towers' is registered with the UPRERA with registration no. UPRERAPRJ12475. Please refer to project details
# on the website of UPRERA www.up-rera.in.
#
# ================================================================================
# Question: At Max Towers, solar heat gain is controlled through which system?
#
# Top 1 | Score: 0.4636475741863251
# PDF: test_pdf_1.pdf
# Page: 13
# Answer Chunk:
#  Max Towers is
# LEED Platinum Certiﬁed.
# Max Towers is a thought leader in sustainability and aims to minimise
# its ecological footprint. To do so is important to us because we feel
# a certain responsibility towards our planet, and we invite you to share
# our enthusiasm for the same.
# Ground-water recharge
# An extensive rainwater
# management system
#
# Top 2 | Score: 0.45900553464889526
# PDF: test_pdf_1.pdf
# Page: 5
# Answer Chunk:
#  Instead, all of our lives are informed by how we work and our work
# is informed by how we live.
# Essentially, we envision Max Towers to be an environment built around
# enhancing and enriching your work and your life, allowing you to truly
# Work Well.
# 9
# 8
#
# Top 3 | Score: 0.45569682121276855
# PDF: test_pdf_1.pdf
# Page: 7
# Answer Chunk:
#  Fully unitised aluminium curtain wall panels Solar heat gain coeﬃ cient of 0.25 Glass units are insulated glass units, 30 mm thick consisting of an 8 mm thick clear heat- strengthened outer lite, 16 mm air space and a 6 mm thick clear fully-tempered inner lite with a Low-E coating Landscaped courtyards 130-seater auditorium Co-working space
#
# ================================================================================
# Question: Most prime location of max towers?
#
# Top 1 | Score: 0.6356809139251709
# PDF: test_pdf_3.pdf
# Page: 35
# Answer Chunk:
#  Max Towers is owned by : Max Towers Pvt. Ltd.(previously known as Wise Zone Builders Pvt. Ltd.),having its Registered ofﬁce Address at :
# Max Towers, L-12, C- 001/A/1, Sector- 16B NOIDA UP 201301, CIN : U70109UP2016PTC087374. Its Occupation Certiﬁcate has been received
#
# Top 2 | Score: 0.6317722797393799
# PDF: test_pdf_1.pdf
# Page: 15
# Answer Chunk:
#  Above Entrance to Max Towers
# Facing page The Box at Max Towers
# 29
# 28
#
# Top 3 | Score: 0.621881365776062
# PDF: test_pdf_1.pdf
# Page: 8
# Answer Chunk:
#  Design
# Nothing about this environment
# or experience is accidental.
# At a glance
# Located in Sector 16B, Noida, Max Towers commands direct access from
# the DND Flyway. Max Towers is walking distance from the metro station
# and minutes away from Delhi’s Central Business District.
# Super built-up area
# Number of ﬂoors
#
# Floor-to-ﬂoor height
#
# ================================================================================
# Question: when was max estates established?
#
# Top 1 | Score: 0.7869311571121216
# PDF: test_pdf_1.pdf
# Page: 35
# Answer Chunk:
#  by the President of India, for his contributions to trade and industry.
# Max Estates
# Established in 2016, Max Estates Limited is the real estate arm
# of Max Group with the vision to bring the Group's values of Sevabhav,
# Excellence and Credibility to the Indian real estate sector.
# The mission of Max Estates is to oﬀer spaces for residential and
#
# Top 2 | Score: 0.7273357510566711
# PDF: test_pdf_3.pdf
# Page: 34
# Answer Chunk:
#  The Max Group is led by its Founder and Chairman Mr. Analjit
# Singh.
# Established in 2016, Max Estates Limited is the real estate
# arm of Max Group with the vision to bring the Group's values
# of Sevabhav, Excellence and Credibility to the Indian real
# estate sector.
# The mission of Max Estates is to offer spaces for commercial
#
# Top 3 | Score: 0.7101759910583496
# PDF: test_pdf_4.pdf
# Page: 39
# Answer Chunk:
#  attention to detail, design and lifestyle. Max
# Estates aspires to be the most trusted Real
# Estate company driven by the desire to enhance
# the well-being of everyone we touch. With an
# exceptional team of engineers, architects, planners,
# specialists, and collaborations with global leaders in
#
# ================================================================================
# Question: What is the Solar Heat Gain Coefficient (SHGC) of the 30 mm thick insulated glass unit used in Max Towers’ façade?
#
# Top 1 | Score: 0.6727583408355713
# PDF: test_pdf_1.pdf
# Page: 7
# Answer Chunk:
#  Fully unitised aluminium curtain wall panels Solar heat gain coeﬃ cient of 0.25 Glass units are insulated glass units, 30 mm thick consisting of an 8 mm thick clear heat- strengthened outer lite, 16 mm air space and a 6 mm thick clear fully-tempered inner lite with a Low-E coating Landscaped courtyards 130-seater auditorium Co-working space
#
# Top 2 | Score: 0.6154541969299316
# PDF: test_pdf_1.pdf
# Page: 9
# Answer Chunk:
#  the overall costs of energy consumption for tenants. Low-E, high performance glass with low reﬂectance 30 mm thick insulated glass units, consisting of – 8 mm thick clear heat-strengthened outer lite – 16 mm air space – 6 mm thick clear fully-tempered inner lite with a Low-E coating Solar heat gain coeﬃcient of 0.25
#
# Top 3 | Score: 0.5686028599739075
# PDF: test_pdf_1.pdf
# Page: 9
# Answer Chunk:
#  – 6 mm thick clear fully-tempered inner lite with a Low-E coating Solar heat gain coeﬃcient of 0.25 Cuts visible light transmission by 34% Detail of façade at Max Towers 16
#
# ================================================================================
# Question: What percentage of visible light transmission is cut by the 30 mm thick insulated glass unit with Low-E coating used in the façade system at Max Towers?
#
# Top 1 | Score: 0.640649676322937
# PDF: test_pdf_1.pdf
# Page: 9
# Answer Chunk:
#  – 6 mm thick clear fully-tempered inner lite with a Low-E coating Solar heat gain coeﬃcient of 0.25 Cuts visible light transmission by 34% Detail of façade at Max Towers 16
#
# Top 2 | Score: 0.581678032875061
# PDF: test_pdf_1.pdf
# Page: 9
# Answer Chunk:
#  the overall costs of energy consumption for tenants. Low-E, high performance glass with low reﬂectance 30 mm thick insulated glass units, consisting of – 8 mm thick clear heat-strengthened outer lite – 16 mm air space – 6 mm thick clear fully-tempered inner lite with a Low-E coating Solar heat gain coeﬃcient of 0.25
#
# Top 3 | Score: 0.5559486150741577
# PDF: test_pdf_1.pdf
# Page: 7
# Answer Chunk:
#  natural light and have a view of the outside Greater versatility in ﬂ oor plan layouts LEED Platinum Façade features Common amenities Technology oﬀ ering Security Electrical Water Low-E, high performance glass with low reﬂ ectance Fully unitised aluminium curtain wall panels Solar heat gain coeﬃ cient of 0.25
#
# ================================================================================
# Question: What is the total Super Built Up Area of Max House located in the Secondary Business District of New Delhi?
#
# Top 1 | Score: 0.8010765314102173
# PDF: test_pdf_2.pdf
# Page: 2
# Answer Chunk:
#  Open for business; In the heart of New Delhi Originally the headquarters of the $3B Max Group, Max House is located at the epicenter of the Secondary Business District of Delhi. Offering ~105,000 sq. ft. of prime real estate spread across 10 floors, Max House is poised to be the new business address in Delhi NCR.
#
# Top 2 | Score: 0.7384942770004272
# PDF: test_pdf_4.pdf
# Page: 39
# Answer Chunk:
#  Located in the Central Business District of South Delhi - the design vocabulary of Max House extends the narrative set by its Industrial vicinity and adapts it for a modern workforce. Max House is LEED Gold certiﬁed for Green Building Strategies and IGBC Gold Rated for Health and Wellness aspects. It integrates itself
#
# Top 3 | Score: 0.6990864872932434
# PDF: test_pdf_4.pdf
# Page: 39
# Answer Chunk:
#  and easily accessible location in the heart of South Delhi. Max House, Okhla 222 Rajpur is a premier residential community located adjacent to the Malsi forest, at the most exclusive address in Dehradun. Spread across 5 acres, 222 Rajpur offers a limited inventory of 22 villas to those discerning homeowners who value
#
# ================================================================================
# Question: What is the green building certification rating of Max House?
#
# Top 1 | Score: 0.639413595199585
# PDF: test_pdf_4.pdf
# Page: 27
# Answer Chunk:
#  Designed Responsibly and Sustainably Green Building Max Square is IGBC Platinum Certiﬁed for Green Building Standards including appropriate orientation, adequate walls and over deck insulation. Furthermore, with MEP interventions and critical design elements of façade, the building fosters a healthy indoor environment and
#
# Top 2 | Score: 0.6096377372741699
# PDF: test_pdf_2.pdf
# Page: 10
# Answer Chunk:
#  Sustainability: LEED Gold Certified Max House is designed to be LEED Gold certified. Max House is a thought leader in sustainability and aims to minimise its ecological footprint. To do so is important to us because we feel a certain responsibility towards our planet, and we invite you to share our enthusiasm
#
# Top 3 | Score: 0.5573997497558594
# PDF: test_pdf_4.pdf
# Page: 39
# Answer Chunk:
#  Located in the Central Business District of South Delhi - the design vocabulary of Max House extends the narrative set by its Industrial vicinity and adapts it for a modern workforce. Max House is LEED Gold certiﬁed for Green Building Strategies and IGBC Gold Rated for Health and Wellness aspects. It integrates itself
#
# ================================================================================
# Question: How long does it take to reach suryaa hotel from Max House?
#
# Top 1 | Score: 0.6477128863334656
# PDF: test_pdf_2.pdf
# Page: 3
# Answer Chunk:
#  The Suryaa 5 minutes Eros Hotel 9 minutes Crowne Plaza 15 minutes Sarovar Portico 8 minutes Strategically located within walking distance of the Okhla NSIC Metro Station, Max House offers excellent accessibility and connectivity to Delhi's various central business districts, airports and residential neighbourhoods.
#
# Top 2 | Score: 0.5969070196151733
# PDF: test_pdf_2.pdf
# Page: 3
# Answer Chunk:
#  25 minutes Terminal 1D (Airport) 30 minutes MG Road (Gurgaon) 40 minutes Jasola 8 minutes -IپWN3IQTI[P 8 minutes New Friends Colony 10 minutes Greater Kailash 10 minutes Connaught Place 22 minutes Kalkaji Interconnect Walking distance 0W\MT[,ZQ^QVO<QUM The Suryaa 5 minutes Eros Hotel 9 minutes Crowne Plaza 15 minutes Sarovar Portico 8 minutes
#
# Top 3 | Score: 0.5166858434677124
# PDF: test_pdf_1.pdf
# Page: 33
# Answer Chunk:
#  station, Max Towers provides excellent connectivity to Delhi's various central business districts, airports and residential neighbourhoods. Facing page Aerial view of Max Towers and Delhi One Sector 16 Metro Station 0.7 km 5 min Connaught Place 15 km 25 min IGI Airport 25 km 45 min Saket 18 km 30 min Gurgaon 32 km 55 min Jasola 12 km 20 min
#
# ================================================================================
# Question: How far is Connaught Place from Max House?
#
# Top 1 | Score: 0.5567854046821594
# PDF: test_pdf_2.pdf
# Page: 8
# Answer Chunk:
#  Entrance to Max House Lobby
#
# Top 2 | Score: 0.5227163434028625
# PDF: test_pdf_2.pdf
# Page: 2
# Answer Chunk:
#  Open for business; In the heart of New Delhi Originally the headquarters of the $3B Max Group, Max House is located at the epicenter of the Secondary Business District of Delhi. Offering ~105,000 sq. ft. of prime real estate spread across 10 floors, Max House is poised to be the new business address in Delhi NCR.
#
# Top 3 | Score: 0.5064576864242554
# PDF: test_pdf_2.pdf
# Page: 15
# Answer Chunk:
#  Railmajra, Tehsil Balachaur, Nawanshehar, Punjab 144533), Spaces at Max House are available for rent and no sale of space is being advertised in said building. UPRERA Registration number: UPRERAPRJ12475 UPRERA website: www.up-rera.in
#
# ================================================================================
# Question: What sustainability certification has Max Square achieved for green building standards?
#
# Top 1 | Score: 0.6758791208267212
# PDF: test_pdf_4.pdf
# Page: 27
# Answer Chunk:
#  Designed Responsibly and Sustainably Green Building Max Square is IGBC Platinum Certiﬁed for Green Building Standards including appropriate orientation, adequate walls and over deck insulation. Furthermore, with MEP interventions and critical design elements of façade, the building fosters a healthy indoor environment and
#
# Top 2 | Score: 0.589626669883728
# PDF: test_pdf_4.pdf
# Page: 28
# Answer Chunk:
#  51
# 52
# Sustainability
# Following our values of conservation and minimizing ecological
# footprint, we have adopted ways in which we can harness the
# power of renewable energy resources and use it to fulﬁl our
# day-to-day demands. Max Square has a ground water recharge
# system, and a waste management including segregation of dry
#
# Top 3 | Score: 0.5287236571311951
# PDF: test_pdf_4.pdf
# Page: 4
# Answer Chunk:
#  3
# 4
# Max Square is designed with focus on the elements of
# nature and nurture, and looks to incorporate the
# aspect of wellness throughout the building. It pays
# attention to the crucial elements that make up a
# modern workplace, including sustainability, design
# and a campus environment, enabling you to not just
# work, but ﬂourish, and grow!
#
# ================================================================================
# Question: What is the total number of parking levels at Max House, including basement, stilt, and podium parking?
#
# Top 1 | Score: 0.6581827998161316
# PDF: test_pdf_1.pdf
# Page: 8
# Answer Chunk:
#  Super built-up area Number of ﬂoors Floor-to-ﬂoor height Typical oﬃce ﬂoor plate size Parking Green rating 52,016 square metres (559,891 square feet) 19 oﬃce ﬂoors 4 amenity ﬂoors 3 level basement car parking 4.3 m minimum for all oﬃce ﬂoors 2,369 square metres (25,500 square feet) 1:700 square feet LEED Platinum
#
# Top 2 | Score: 0.5915132761001587
# PDF: test_pdf_2.pdf
# Page: 2
# Answer Chunk:
#  happier community. Building Height 40 m Total Number of Floors 1 Basement Parking 1 Stilt Parking 2 Podium Level Parking 8 Tenant Floors Terrace Typical Floor Plate Size 13,000 sq. ft. Green Rating LEED Gold Floor Condition Warmshell with screeding 3Ma.IK\[ 1,05,425 sq.ft. Super Built Up Area
#
# Top 3 | Score: 0.5735787153244019
# PDF: test_pdf_1.pdf
# Page: 7
# Answer Chunk:
#  52,016 square metres (559,891 square feet) 19 oﬃ ce ﬂ oors 4 amenity ﬂ oors 3 level basement car parking 2,369 square metres (25,500 square feet) Floor eﬃ ciency @60% Optimum leasing depth allows employees even in the centre of the building to enjoy natural light and have a view of the outside Greater versatility in ﬂ oor plan layouts
#
# ================================================================================
# Question: Which airport terminal is specifically mentioned as being 30 minutes away?
#
# Top 1 | Score: 0.5442451238632202
# PDF: test_pdf_2.pdf
# Page: 3
# Answer Chunk:
#  25 minutes Terminal 1D (Airport) 30 minutes MG Road (Gurgaon) 40 minutes Jasola 8 minutes -IپWN3IQTI[P 8 minutes New Friends Colony 10 minutes Greater Kailash 10 minutes Connaught Place 22 minutes Kalkaji Interconnect Walking distance 0W\MT[,ZQ^QVO<QUM The Suryaa 5 minutes Eros Hotel 9 minutes Crowne Plaza 15 minutes Sarovar Portico 8 minutes
#
# Top 2 | Score: 0.4934842884540558
# PDF: test_pdf_1.pdf
# Page: 33
# Answer Chunk:
#  15 km 25 min IGI Airport 25 km 45 min Saket 18 km 30 min Gurgaon 32 km 55 min Jasola 12 km 20 min Nehru Place 11 km 20 min New Delhi Railway Station 15.5 km 30 min India Gate 13.5 km 20 min Noida City Centre 6 km 10 min 64
#
# Top 3 | Score: 0.4708949029445648
# PDF: test_pdf_4.pdf
# Page: 11
# Answer Chunk:
#  Metro Station 15 min (11.2 Km) Nehru Place (SBD) Okhla Bird Sanctuary Metro Station 12 min (9.2 Km) Noida-Greater Noida Expressway Jaypee Hospital 5 min (2 Km) Noida Sector 142 Metro Station 8 min (3.6 Km) Amity University 15 min (10.6 Km) Upcoming Jewar Airport 60 min (60 Km) 17 18 IGI Airport Upcoming Jewar Airport Okhla Bird Sanctuary
#
# ================================================================================
# Question: Which airport is mentioned as upcoming near Max Square?
#
# Top 1 | Score: 0.5970699787139893
# PDF: test_pdf_4.pdf
# Page: 11
# Answer Chunk:
#  Developed in one of the fastest growing premium locations of NCR,
# Noida, Max Square is conveniently accessible through both road
# and metro. To further ease the accessibility, shuttle service will be
# available from the nearest metro station. With the upcoming Jewar
# International Airport a marker of the increasing development of the
#
# Top 2 | Score: 0.592328667640686
# PDF: test_pdf_4.pdf
# Page: 11
# Answer Chunk:
#  International Airport a marker of the increasing development of the
# area, Noida is seeing an increase in government investment, as well
# as growth of social infrastructure and employment opportunities.
# Meticulously chosen to be created especially in Sector 129 in Noida,
# Max Square fosters  connectivity to all the prominent sectors of
#
# Top 3 | Score: 0.5490851402282715
# PDF: test_pdf_4.pdf
# Page: 11
# Answer Chunk:
#  Upcoming Jewar Airport
# 60 min (60 Km)
# 17
# 18
# IGI Airport
# Upcoming Jewar Airport
# Okhla Bird Sanctuary
# Metro Station
# Noida Sector 142
# Metro Station
# Botanical Garden
# Metro Station
# Rajiv Chowk Metro Station
# Connaught Place (CBD)
# Mall of India
# Jaypee Hospital
# Amity University
# Radisson Blu Hotel
# Nehru Place (SBD)
#
# ================================================================================
# Question: What is the name of the central courtyard forest inside the building?
#
# Top 1 | Score: 0.7327606081962585
# PDF: test_pdf_4.pdf
# Page: 8
# Answer Chunk:
#  Introducing The Central
# Forest Courtyard
# *Artistic impression
# 11
# 12
#
# Top 2 | Score: 0.5966455340385437
# PDF: test_pdf_1.pdf
# Page: 11
# Answer Chunk:
#  of your day provides you with a connection to the natural world.
# From the façade that modulates sunlight to mimic a dense forest
# canopy, to the very air you breathe inside Max Towers, everything
# you experience is designed to enhance the eﬀects of nature on
# creativity, productivity and wellness.
# View towards courtyard on the 20th ﬂoor
# 21
#
# Top 3 | Score: 0.5838689804077148
# PDF: test_pdf_3.pdf
# Page: 24
# Answer Chunk:
#  street view, Courtyard villas
# spectacular view of the malsi reserve forest
#
# ================================================================================
# Question: What is the green building rating of Max Towers?
#
# Top 1 | Score: 0.6392043232917786
# PDF: test_pdf_1.pdf
# Page: 13
# Answer Chunk:
#  Max Towers is
# LEED Platinum Certiﬁed.
# Max Towers is a thought leader in sustainability and aims to minimise
# its ecological footprint. To do so is important to us because we feel
# a certain responsibility towards our planet, and we invite you to share
# our enthusiasm for the same.
# Ground-water recharge
# An extensive rainwater
# management system
#
# Top 2 | Score: 0.634631872177124
# PDF: test_pdf_1.pdf
# Page: 3
# Answer Chunk:
#  experiences.
# Our intention with Max Towers is to blend thoughtful design and
# superior hospitality to create an environment, which integrates work
# and life, nurturing a more productive, healthier and happier community.
# Excerpted from Deloitte Review, July 2017
# Excerpted from CBRE Global Occupier Survey, 2017
# Corporate culture is evolving.
#
# Top 3 | Score: 0.6270782947540283
# PDF: test_pdf_4.pdf
# Page: 27
# Answer Chunk:
#  Designed Responsibly and Sustainably Green Building Max Square is IGBC Platinum Certiﬁed for Green Building Standards including appropriate orientation, adequate walls and over deck insulation. Furthermore, with MEP interventions and critical design elements of façade, the building fosters a healthy indoor environment and
#
# ================================================================================
# Question: What is the minimum ceiling height on office floors?
#
# Top 1 | Score: 0.65664142370224
# PDF: test_pdf_1.pdf
# Page: 18
# Answer Chunk:
#  Tenant Floors Max Towers provides you with a state-of-the-art blank slate workspace that you can fully customise to suit your needs. Designed such that 90% of regular occupied space gets direct line-of-sight to the outside environment, the average ceiling height on our tenant ﬂoor plates is 4.3 metres. Combined with optimum column
#
# Top 2 | Score: 0.5306549668312073
# PDF: test_pdf_4.pdf
# Page: 33
# Answer Chunk:
#  Early Learning Centre
# Conference Rooms
# Number of Floors
# 12 Ofﬁce Floors
# 1 Retail Floor
# 3 Levels of Parking in Basement and Lower Ground
# 10 Passenger Elevators
# 2 Service Elevators
# 2 Shuttle Elevators
# Ceiling Height: 4.03 m (ﬂoor-to-ﬂoor)
# Typical Floor Size:
# ~4,975 sq.mtr. (53,551 sq.ft.)
# Power Back Up: 100% Power Back Up
# Water
#
# Top 3 | Score: 0.49914413690567017
# PDF: test_pdf_3.pdf
# Page: 18
# Answer Chunk:
#  Generous ceiling height (10.5 ft)
# Maintenance free facade
# Insulated premium windows
# Perlato marble ﬂooring
# Landscaped terrace
# COURTYARD VILLAS
# Units 5
# Plot size range 364-565 sq.m.
# Built up area 4197 sq.ft.²
# Carpet area 3276 sq.ft.²
# Balcony area 130 sq.ft.²
#
# ================================================================================
# Question: What is the super built-up area of Max Towers?
#
# Top 1 | Score: 0.6815927028656006
# PDF: test_pdf_1.pdf
# Page: 4
# Answer Chunk:
#  Max Towers is an attempt
# to provide you with
#
# – an agile workplace that responds to work expansion and contraction
# with ease.
#
# – collaborative spaces like co-working zones and a ﬂexible multi-use
# dining area that allow you to retain your space eﬃciency.
#
# – thoughtfully designed amenities and conveniences.
#
# Top 2 | Score: 0.6810997128486633
# PDF: test_pdf_1.pdf
# Page: 8
# Answer Chunk:
#  2,369 square metres (25,500 square feet)
# 1:700 square feet
# LEED Platinum
# View of Max Towers from the DND Flyway
#
# Top 3 | Score: 0.6788886785507202
# PDF: test_pdf_1.pdf
# Page: 5
# Answer Chunk:
#  Instead, all of our lives are informed by how we work and our work
# is informed by how we live.
# Essentially, we envision Max Towers to be an environment built around
# enhancing and enriching your work and your life, allowing you to truly
# Work Well.
# 9
# 8
#
# ================================================================================
# Question: What is the parking ratio provided?
#
# Top 1 | Score: 0.651154637336731
# PDF: test_pdf_1.pdf
# Page: 8
# Answer Chunk:
#  Super built-up area Number of ﬂoors Floor-to-ﬂoor height Typical oﬃce ﬂoor plate size Parking Green rating 52,016 square metres (559,891 square feet) 19 oﬃce ﬂoors 4 amenity ﬂoors 3 level basement car parking 4.3 m minimum for all oﬃce ﬂoors 2,369 square metres (25,500 square feet) 1:700 square feet LEED Platinum
#
# Top 2 | Score: 0.5663934946060181
# PDF: test_pdf_1.pdf
# Page: 7
# Answer Chunk:
#  52,016 square metres (559,891 square feet) 19 oﬃ ce ﬂ oors 4 amenity ﬂ oors 3 level basement car parking 2,369 square metres (25,500 square feet) Floor eﬃ ciency @60% Optimum leasing depth allows employees even in the centre of the building to enjoy natural light and have a view of the outside Greater versatility in ﬂ oor plan layouts
#
# Top 3 | Score: 0.5208175182342529
# PDF: test_pdf_4.pdf
# Page: 33
# Answer Chunk:
#  61 62 Fact Sheet Type of building – Commercial Leasable Area: 6,71,937 sq.ft. Sustainability : IGBC Platinum Certiﬁed for Green Building Standards Car Parking: 886 Common Amenities Landscaped Courtyard of 10,690 sq.ft. Area Food Court Multipurpose Hall Early Learning Centre Conference Rooms Number of Floors 12 Ofﬁce Floors 1 Retail Floor
#
# ================================================================================
# Question: Which seismic zone is the building designed for?
#
# Top 1 | Score: 0.6365247964859009
# PDF: test_pdf_3.pdf
# Page: 31
# Answer Chunk:
#  better sound insulation between ﬂoors.
# Structure built using only primary steel
# sources (no secondary/recycled steel)
# to ensure consistent quality, durability,
# maximum safety and stability of all
# homes.
# Structural design adheres to Seismic
# Zone 4.
# SAFETY & SECURITY
# 24 hour site management and round the
# clock security.
#
# Top 2 | Score: 0.5040109157562256
# PDF: test_pdf_1.pdf
# Page: 7
# Answer Chunk:
#  Fact sheet
# Iconic presence
# Architects
# Super built-up area
# Number of ﬂ oors
# Typical ﬂ oor size
# Eﬃ  ciency
# Sustainability
# Parking
# Earthquake
# resistance
# HVAC system
# design parameters
# Air treatment
# Power backup
# Ceiling height
# Back-of-house
# facilities
# 1:700 square feet
# Designed for Seismic Zone-V
# 23˚C dry-bulb temperature ±1˚C in oﬃ  ces
#
# Top 3 | Score: 0.45151275396347046
# PDF: test_pdf_3.pdf
# Page: 31
# Answer Chunk:
#  every residence
# Public areas such as kitchen, staff
# rooms, service and utility have been
# separated from the private living spaces
# All residences offer a bedroom on the
# ground ﬂoor for easy accessibility
# STRUCTURAL DESIGN
# All residences have been constructed
# using RCC ﬂat slab for an efﬁcient
# structural system, greater ﬂoor to ﬂoor

# %%
import time
import numpy as np
import re

def normalize(text):
    text = text.lower()
    text = text.replace("-", " ")
    text = text.replace("~", "")
    text = re.sub(r"\s+", " ", text)
    return text.strip()

def clean_number(text):
    # Remove commas from numbers
    return re.sub(r"(?<=\d),(?=\d)", "", text)

def contains_answer(chunk_text, expected):
    chunk_text = normalize(chunk_text)
    expected = normalize(expected)

    chunk_text = clean_number(chunk_text)
    expected = clean_number(expected)

    expected_words = expected.split()

    return all(word in chunk_text for word in expected_words)



top1_correct = 0
top3_correct = 0
latencies = []

top1_failed = []
top3_failed = []

total_questions = len(eval_df)

for _, row in eval_df.iterrows():
    question = row["question"]
    expected = row["expected_answer_keyword"]

    start = time.time()
    results = retrieve_faiss(question, top_k=3)
    latency = time.time() - start
    latencies.append(latency)

    # ---------- Top-1 ----------
    if contains_answer(results[0][0]["text"], expected):
        top1_correct += 1
    else:
        top1_failed.append({
            "question": question,
            "expected": expected,
            "retrieved_top1": results[0][0]["text"][:400]
        })

    # ---------- Top-3 ----------
    found_in_top3 = False
    for chunk, score in results:
        if contains_answer(chunk["text"], expected):
            found_in_top3 = True
            break

    if found_in_top3:
        top3_correct += 1
    else:
        top3_failed.append({
            "question": question,
            "expected": expected,
            "retrieved_chunks": [chunk["text"][:300] for chunk, _ in results]
        })


# -------- Final Metrics --------
avg_latency = np.mean(latencies)
p95_latency = np.percentile(latencies, 95)

print("\n===== FINAL METRICS =====")
print("Total Questions:", total_questions)
print("Top-1 Accuracy:", round(top1_correct / total_questions, 3))
print("Top-3 Accuracy:", round(top3_correct / total_questions, 3))
print("Average Latency (s):", round(avg_latency, 4))
print("P95 Latency (s):", round(p95_latency, 4))


# -------- Failure Analysis --------
print("\n===== TOP-1 FAILED QUESTIONS =====")
for item in top1_failed:
    print("\nQuestion:", item["question"])
    print("Expected:", item["expected"])
    print("Top-1 Retrieved Snippet:", item["retrieved_top1"])
    print("-" * 60)


print("\n===== TOP-3 FAILED QUESTIONS =====")
for item in top3_failed:
    print("\nQuestion:", item["question"])
    print("Expected:", item["expected"])
    print("Retrieved Top-3 Snippets:")
    for snippet in item["retrieved_chunks"]:
        print("->", snippet)
    print("-" * 60)
# Out:
# ===== FINAL METRICS =====
# Total Questions: 20
# Top-1 Accuracy: 0.8
# Top-3 Accuracy: 0.85
# Average Latency (s): 0.0102
# P95 Latency (s): 0.0207
#
# ===== TOP-1 FAILED QUESTIONS =====
#
# Question: At Max Towers, solar heat gain is controlled through which system?
# Expected: vertical-fin
# Top-1 Retrieved Snippet: Max Towers is
# LEED Platinum Certiﬁed.
# Max Towers is a thought leader in sustainability and aims to minimise
# its ecological footprint. To do so is important to us because we feel
# a certain responsibility towards our planet, and we invite you to share
# our enthusiasm for the same.
# Ground-water recharge
# An extensive rainwater
# management system
# ------------------------------------------------------------
#
# Question: What is the green building certification rating of Max House?
# Expected: LEED Gold
# Top-1 Retrieved Snippet: Designed Responsibly and Sustainably Green Building Max Square is IGBC Platinum Certiﬁed for Green Building Standards including appropriate orientation, adequate walls and over deck insulation. Furthermore, with MEP interventions and critical design elements of façade, the building fosters a healthy indoor environment and
# ------------------------------------------------------------
#
# Question: How far is Connaught Place from Max House?
# Expected: 11
# Top-1 Retrieved Snippet: Entrance to Max House Lobby
# ------------------------------------------------------------
#
# Question: What is the super built-up area of Max Towers?
# Expected: 52016
# Top-1 Retrieved Snippet: Max Towers is an attempt
# to provide you with
#
# – an agile workplace that responds to work expansion and contraction
# with ease.
#
# – collaborative spaces like co-working zones and a ﬂexible multi-use
# dining area that allow you to retain your space eﬃciency.
#
# – thoughtfully designed amenities and conveniences.
# ------------------------------------------------------------
#
# ===== TOP-3 FAILED QUESTIONS =====
#
# Question: At Max Towers, solar heat gain is controlled through which system?
# Expected: vertical-fin
# Retrieved Top-3 Snippets:
# -> Max Towers is
# LEED Platinum Certiﬁed.
# Max Towers is a thought leader in sustainability and aims to minimise
# its ecological footprint. To do so is important to us because we feel
# a certain responsibility towards our planet, and we invite you to share
# our enthusiasm for the same.
# Ground-water re
# -> Instead, all of our lives are informed by how we work and our work
# is informed by how we live.
# Essentially, we envision Max Towers to be an environment built around
# enhancing and enriching your work and your life, allowing you to truly
# Work Well.
# 9
# 8
# -> Fully unitised aluminium curtain wall panels Solar heat gain coeﬃ cient of 0.25 Glass units are insulated glass units, 30 mm thick consisting of an 8 mm thick clear heat- strengthened outer lite, 16 mm air space and a 6 mm thick clear fully-tempered inner lite with a Low-E coating Landscaped courtya
# ------------------------------------------------------------
#
# Question: How far is Connaught Place from Max House?
# Expected: 11
# Retrieved Top-3 Snippets:
# -> Entrance to Max House Lobby
# -> Open for business; In the heart of New Delhi Originally the headquarters of the $3B Max Group, Max House is located at the epicenter of the Secondary Business District of Delhi. Offering ~105,000 sq. ft. of prime real estate spread across 10 floors, Max House is poised to be the new business address
# -> Railmajra, Tehsil Balachaur, Nawanshehar, Punjab 144533), Spaces at Max House are available for rent and no sale of space is being advertised in said building. UPRERA Registration number: UPRERAPRJ12475 UPRERA website: www.up-rera.in
# ------------------------------------------------------------
#
# Question: What is the super built-up area of Max Towers?
# Expected: 52016
# Retrieved Top-3 Snippets:
# -> Max Towers is an attempt
# to provide you with
#
# – an agile workplace that responds to work expansion and contraction
# with ease.
#
# – collaborative spaces like co-working zones and a ﬂexible multi-use
# dining area that allow you to retain your space eﬃciency.
#
# – thoughtfully designed amenities and
# -> 2,369 square metres (25,500 square feet)
# 1:700 square feet
# LEED Platinum
# View of Max Towers from the DND Flyway
# -> Instead, all of our lives are informed by how we work and our work
# is informed by how we live.
# Essentially, we envision Max Towers to be an environment built around
# enhancing and enriching your work and your life, allowing you to truly
# Work Well.
# 9
# 8
# ------------------------------------------------------------
